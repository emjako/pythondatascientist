# %% [markdown]
# # Chapitre 6 - Différentes utilisations dumachine learning avec Python (4ème partie)

# %% [markdown]
# ## 6.7 Le deep learning avec Keras
#
# ### 6.7.2 Principe d’un réseau de neurone et première utilisation avec Keras
#
# Le package Keras que nous avons installé est basé sur une structure extrêmement
# simple à mettre en oeuvre. On commence par définir le type de réseau utilisé. Dans
# cet ouvrage, il s’agira de réseaux séquentiels.

# %% [markdown]
# Si nous prenons les données sur les télécommunications que nous avons utilisées
# précédemment, nous pouvons simplement utiliser Keras pour créer un réseau de neurones assez évolué (on suppose ici que les données ont été préparées comme
# dans la première partie de ce chapitre avec Scikit-Learn) :

# %%
import pandas as pd
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.layers import BatchNormalization, Activation
# Out:
# WARNING:tensorflow:From c:\Users\ej\miniconda3\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
x=pd.read_csv("../data/x_telecom.csv",index_col=0)
y=pd.read_csv("../data/y_telecom.csv",index_col=0)

# %%
from sklearn.model_selection import train_test_split
# on sépare nos données en apprentissage/validation avec Scikit-Learn
x_train, x_test, y_train, y_test=train_test_split(x,y,test_size=0.2)

# %%
# on crée le modèle
model = Sequential()
# Out:
# WARNING:tensorflow:From c:\Users\ej\miniconda3\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
# on ajoute des couches avec des fonctions d’activation
model.add(Dense(50, input_shape=(21,)))
model.add(Activation("relu"))
# cette couche permet de normaliser les données
model.add(BatchNormalization())
# cette couche va faire en sorte d’éviter l’overfitting
model.add(Dropout(0.1))
# on ajoute un autre groupe de couches
model.add(Dense(10))
model.add(Activation("relu"))
model.add(BatchNormalization())
model.add(Dropout(0.1))
# on ajoute la couche de sortie
model.add(Dense(1))
model.add(Activation('sigmoid'))

# %%
# on définit la fonction de perte et la fonction d’optiimsation
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=["accuracy"])
# Out:
# WARNING:tensorflow:From c:\Users\ej\miniconda3\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
# on ajuste le modèle
model.fit(x_train, y_train, batch_size=100, epochs=100)
# Out:
# Epoch 1/100
# WARNING:tensorflow:From c:\Users\ej\miniconda3\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\ej\miniconda3\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 27/27 [==============================] - 1s 2ms/step - loss: 0.8233 - accuracy: 0.5225
# Epoch 2/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6724 - accuracy: 0.6182
# Epoch 3/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6114 - accuracy: 0.6782
# Epoch 4/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5651 - accuracy: 0.7359
# Epoch 5/100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.5057 - accuracy: 0.7824
# Epoch 6/100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4760 - accuracy: 0.8132
# Epoch 7/100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4408 - accuracy: 0.8428
# Epoch 8/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4030 - accuracy: 0.8548
# Epoch 9/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.3843 - accuracy: 0.8653
# Epoch 10/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.3561 - accuracy: 0.8717
# Epoch 11/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.3238 - accuracy: 0.8916
# Epoch 12/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.3087 - accuracy: 0.8897
# Epoch 13/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2802 - accuracy: 0.9025
# Epoch 14/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2782 - accuracy: 0.9044
# Epoch 15/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2645 - accuracy: 0.9107
# Epoch 16/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2596 - accuracy: 0.9074
# Epoch 17/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2446 - accuracy: 0.9182
# Epoch 18/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2432 - accuracy: 0.9119
# Epoch 19/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2277 - accuracy: 0.9212
# Epoch 20/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2253 - accuracy: 0.9216
# Epoch 21/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2205 - accuracy: 0.9194
# Epoch 22/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2178 - accuracy: 0.9231
# Epoch 23/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2081 - accuracy: 0.9269
# Epoch 24/100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2142 - accuracy: 0.9194
# Epoch 25/100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.2052 - accuracy: 0.9269
# Epoch 26/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2000 - accuracy: 0.9291
# Epoch 27/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1936 - accuracy: 0.9306
# Epoch 28/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1970 - accuracy: 0.9314
# Epoch 29/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.
100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.1214 - accuracy: 0.9621
# Epoch 97/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1141 - accuracy: 0.9610
# Epoch 98/100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.1138 - accuracy: 0.9644
# Epoch 99/100
# 27/27 [==============================] - 0s 1ms/step - loss: 0.1249 - accuracy: 0.9610
# Epoch 100/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1118 - accuracy: 0.9599

# %%
model.predict(x_test)
# Out:
# 21/21 [==============================] - 0s 995us/step
# array([[4.33706027e-03],
#        [1.62187126e-02],
#        [9.12631601e-02],
#        [4.55092901e-04],
#        [1.81017127e-02],
#        [1.22207697e-04],
#        [1.89909950e-01],
#        [7.61536896e-01],
#        [1.21815037e-02],
#        [2.01128814e-02],
#        [7.30563945e-04],
#        [1.05901714e-02],
#        [1.23345843e-02],
#        [5.88291907e-04],
#        [5.94911516e-01],
#        [1.01362318e-02],
#        [2.16161590e-02],
#        [4.70777135e-03],
#        [6.69595078e-02],
#        [7.35961080e-01],
#        [1.75070413e-03],
#        [1.51974216e-01],
#        [2.91367550e-03],
#        [7.95054659e-02],
#        [9.83344042e-04],
#        [2.79635860e-04],
#        [9.98924136e-01],
#        [2.77857780e-02],
#        [2.64880800e-04],
#        [1.38726672e-02],
#        [5.53292874e-03],
#        [1.76508294e-03],
#        [2.04201955e-02],
#        [2.16491311e-03],
#        [6.28077378e-03],
#        [3.69932997e-04],
#        [1.19393202e-03],
#        [1.37351733e-03],
#        [2.49857176e-02],
#        [1.00111333e-03],
#        [3.29013467e-02],
#        [3.33386421e-01],
#        [9.74621475e-01],
#        [2.03186879e-03],
#        [5.14498539e-03],
#        [9.99950826e-01],
#        [2.39174124e-02],
#        [1.14505015e-01],
#        [1.13489842e-02],
#        [5.99296242e-02],
#        [7.34304870e-03],
#        [1.99608295e-03],
#        [6.35471020e-04],
#        [5.14305709e-03],
#        [1.40939606e-02],
#        [7.02355115e-04],
#        [1.96756516e-02],
#        [1.36030950e-02],
#        [9.81526196e-01],
#        [1.77250709e-02],
#        [2.97856718e-01],
#        [1.51628302e-02],
#        [4.03154548e-03],
#        [1.62045676e-02],
#        [8.02350405e-04],
#        [3.59238521e-03],
#        [9.60674733e-02],
#        [3.33100586e-04],
#        [5.46749542e-03],
#        [1.61996356e-03],
#        [2.76666973e-02],
#        [2.65599880e-02],
#        [9.77874577e-01],
#        [5.46631590e-03],
#        [2.42500324e-02],
#        [9.44552422e-01],
#        [6.43303851e-04],
#        [5.35274972e-04],
#        [6.66690432e-03],
#        [5.90142645e-02],
#        [3.06321337e-04],
#        [2.30100867e-03],
#        [1.33372605e-01],
#        [9.99576747e-01],
#        [4.18281883e-01],
#        [1.67596024e-02],
#        [9.99957681e-01],
#        [5.96460467e-03],
#        [2.21085884e-02],
#        [4.05512564e-03],
#        [1.28095900e-03],
#        [1.43163034e-03],
#        [1.83728570e-03],
#        [1.07369549e-03],
#        [1.65546036e-04],
#        [2.82971710e-02],
#        [7.85122871e-01],
#        [5.09441714e-04],
#        [5.67595300e-04],
#        [1.76668423e-03],
#        [7.48850172e-03],
#        [9.99879360e-01],
#        [7.93806557e-03],
#        [3.81729472e-03],
#        [9.52976011e-03],
#        [5.53027391e-01],
#        [3.07849459e-02],
#        [4.71091531e-02],
#        [6.69705856e-04],
#        [8.50305334e-02],
#        [2.08523646e-02],
#        [1.08796416e-03],
#        [8.49749863e-01],
#        [1.36239760e-04],
#        [1.30042117e-02],
#        [1.26223802e-03],
#        [2.17885850e-03],
#        [3.30070732e-03],
#        [6.80540747e-04],
#        [4.00986057e-03],
#        [2.63262168e-02],
#        [1.12755690e-03],
#        [5.50606113e-04],
#        [1.85735468e-02],
#        [1.30505741e-01],
#        [9.89037514e-01],
#        [5.06902300e-02],
#        [2.00775499e-03],
#        [8.30755770e-01],
#        [6.49914192e-03],
#        [8.20518704e-04],
#        [3.69185512e-03],
#        [4.82517183e-02],
#        [3.28617846e-03],
#        [7.54193345e-04],
#        [2.26827804e-03],
#        [1.36174792e-02],
#        [4.93908674e-03],
#        [8.59055102e-01],
#        [1.01382760e-02],
#        [1.56784847e-01],
#        [2.98709050e-03],
#        [4.92792167e-02],
#        [1.02687236e-02],
#        [1.07238698e-03],
#        [1.20647559e-02],
#        [2.27839183e-02],
#        [2.69069728e-02],
#        [9.98646677e-01],
#        [2.22754609e-02],
#        [1.06595438e-02],
#        [2.48216704e-01],
#        [7.10955402e-03],
#        [2.73265913e-02],
#        [1.09943487e-02],
#        [8.90209433e-03],
#        [1.36414223e-04],
#        [1.30569376e-03],
#        [1.21042989e-01],
#        [2.09365715e-03],
#        [2.04805471e-03],
#        [1.01817936e-01],
#        [3.09456547e-04],
#        [4.96246219e-02],
#        [3.22338156e-02],
#        [7.78681412e-02],
#        [2.09572352e-02],
#        [3.36199254e-02],
#        [6.00142069e-02],
#        [8.51047039e-02]], dtype=float32)

# %%
# on calcule l’AUC pour les données de validation
from sklearn.metrics import roc_auc_score
print("AUC pour RN :", roc_auc_score(y_test,
                                     model.predict(x_test).reshape(-1)))
# Out:
# 21/21 [==============================] - 0s 901us/step
# AUC pour RN : 0.9055933708197693

# %% [markdown]
# Les réseaux de neurones sont des méthodes extrêmement efficaces à condition
# de bien les paramétrer ce qui peut s‘avérer très difficile.

# %% [markdown]
# ### 6.7.3 Le deep learning et les réseaux de neurones à convolutions

# %% [markdown]
# On va maintenant travailler sur des images. On prendra les données fashion-mnist :

# %%
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Conv2D, MaxPool2D
from tensorflow.keras.datasets import fashion_mnist

# %%
# récupération des données
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

# les données sont transformées pour passer sous un format d’image
# standard avec des valeurs entre 0 et 1
x_train = (x_train/255).reshape(x_train.shape[0], 28, 28,1)
x_test = (x_test/255).reshape(x_test.shape[0], 28, 28,1)

# passage à 10 colonnes pour y(une par modalité)
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# %%
# construction du modèle
model = Sequential()
model.add(Conv2D(32, (3, 3), activation = 'relu', input_shape = (28,28,1)))
model.add(Conv2D(32, (3, 3), activation = 'relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax'))
# Out:
# WARNING:tensorflow:From c:\Users\ej\miniconda3\lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %%
# compilation du modèle
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
# ajustement du modèle
model.fit(x_train, y_train, batch_size=100, epochs=10, verbose=1)
# Out:
# Epoch 1/10
# 600/600 [==============================] - 11s 17ms/step - loss: 0.5517 - accuracy: 0.8042
# Epoch 2/10
# 600/600 [==============================] - 10s 17ms/step - loss: 0.3615 - accuracy: 0.8721
# Epoch 3/10
# 600/600 [==============================] - 10s 17ms/step - loss: 0.3111 - accuracy: 0.8874
# Epoch 4/10
# 600/600 [==============================] - 11s 18ms/step - loss: 0.2784 - accuracy: 0.8990
# Epoch 5/10
# 600/600 [==============================] - 11s 18ms/step - loss: 0.2545 - accuracy: 0.9075
# Epoch 6/10
# 600/600 [==============================] - 10s 17ms/step - loss: 0.2362 - accuracy: 0.9139
# Epoch 7/10
# 600/600 [==============================] - 11s 18ms/step - loss: 0.2201 - accuracy: 0.9191
# Epoch 8/10
# 600/600 [==============================] - 11s 18ms/step - loss: 0.2095 - accuracy: 0.9219
# Epoch 9/10
# 600/600 [==============================] - 10s 17ms/step - loss: 0.1970 - accuracy: 0.9263
# Epoch 10/10
# 600/600 [==============================] - 11s 18ms/step - loss: 0.1847 - accuracy: 0.9310

# %%
# evaluation du modèle
score = model.evaluate(x_test, y_test, verbose=0)

# %% [markdown]
# Nous avons appliqué deux couches de convolutions à 32 neurones avec une taille
# de fenêtre de 3 par 3. Puis une couche de pooling avec une réduction sur des fenêtres
# de 2 par 2. Nous obtenons les résultats suivants :

# %%
# obtention de l’accuracy sur les données de validation
print("Pourcentage de bien classées :", score[1])
# Out:
# Pourcentage de bien classées : 0.9189000129699707

# %% [markdown]
# On voit qu’on est au-delà de 92 % bien classés sur l’échantillon de validation.
# Dans notre cas, on a utilisé des images directement dans le package Keras.

# %% [markdown]
# Généralement, les images sont stockées dans des répertoires différents. Keras
# possède de nombreux outils pour charger ces images, on peut par exemple utiliser
# ImageDataGenerator :

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# on définit un générateur qui pourrait modifier nos images
# (dans ce cas on passe en float 0 à 1)
train_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

# on définit le dossier dans lequel se trouve les images
train_generator = train_datagen.flow_from_directory('../data/',target_size=(150, 150),
                                                    batch_size=32,class_mode='binary')
# on définit le dossier dans lequel se trouve les images
validation_generator = test_datagen.flow_from_directory('../data/',
                                                        target_size=(150, 150),
                                                        batch_size=32,
                                                        class_mode='binary')
# Out:
# Found 0 images belonging to 0 classes.
# Found 0 images belonging to 0 classes.

# %% [raw]
# # on ajuste notre modèle de deep learning avec les images
# # de nos dossiers
# model.fit_generator(train_generator,epochs=50,
#                     validation_data=validation_generator)

# %% [markdown]
# Vous avez maintenant tous les outils pour vous lancer dans la construction de
# réseaux de deep learning avec Python.

# %% [markdown]
# ### 6.7.4 Aller plus loin : génération de features, transfer learning, RN, GAN …
# On charge facilement un modèle avec :

# %%
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.applications.resnet50 import decode_predictions
import numpy as np

# %%
# on utilise le modèle ResNet50
model = ResNet50(weights='imagenet')

# %%
# on récupère une nouvelle image
img_path = '../data/elephant.png'
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# %%
# on applique le modèle
preds = model.predict(x)
print('Prédit (classe/ %):', decode_predictions(preds, top=1)[0])
# Out:
# 1/1 [==============================] - 1s 698ms/step
# Prédit (classe/ %): [('n02504458', 'African_elephant', 0.6474533)]

# %% [markdown]
# On obtient donc un résultat à partir du modèle chargé. On pourra utiliser ce modèle
# et ses poids dans des couches intermédiaires de notre modèle.

# %% [markdown]
# Dans ce cas, on a chargé un modèle et on lui a fourni une photographie d’éléphant.
# Le modèle considère que c’est un éléphant d’Afrique à 87%.

# %% [markdown]
# Nous avons effectué un panorama approfondi de l’utilisation de Python
# pour faire du machine learning, du deep learning et du traitement des
# données textuelles. Python ressort comme un langage adapté à toutes
# ces approches et un outil indispensable pour le data scientist.
